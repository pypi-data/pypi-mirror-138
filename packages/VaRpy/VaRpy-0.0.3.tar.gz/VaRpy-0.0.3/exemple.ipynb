# %%
import varpy
from varpy import EVT_VaR,Student_VaR,Normal_VaR
import numpy as np 
import matplotlib.pyplot as plt 
from varpy.Backtester.bktst import Backtest
from varpy.Backtester.time_Significance import Testing
from varpy.Backtester.chtest import Bootstrap
import warnings
warnings.filterwarnings("ignore")

# %%
from varpy.data.SPX import load as d1
data = d1().values.reshape(-1,)* 100
data
# Out:
# array([-3.83446681,  0.1922183 ,  0.09556781, ..., -1.10373785,
#        -1.89148219,  0.27717389])

# %%
VaR,CVaR = Normal_VaR(data ,0.01,7)
print(VaR,CVaR)
# Out:
# -3.2345688049767327 -3.7118694196885316

# %%
VaR , CVaR = Backtest(data,52,2,0.05,model = 'Gaussian')

# %%
fig = plt.figure(figsize=(15,5))
plt.plot(data[52:])
plt.plot(VaR)
plt.plot(CVaR)
plt.show()

# %%
ts = Testing(data,VaR,CVaR,52,0.05)
print(ts.summary)
# Out:
# Outputs                                    Statistics
# ---------------------------------------  ------------
# Number of VaR Violations:                 334
# Number of CVaR Violations:                193
# Christophersen Test:                        7.008
# Prob (Z-statistic):                         0.0003698
# Quantile ratio:                             1.23647
# Bootstrap Quantile ratio Prob (T-stat):     0.87
# Kupiec Test:                               12.553
# TUFF Test:                                  5.96
# Hass Test:                                 18.503
